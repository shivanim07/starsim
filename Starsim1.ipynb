# %%
#pip install starsim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.1/158.1 kB 2.7 MB/s eta 0:00:00.4 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 5.9 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.2/233.2 kB 3.7 MB/s eta 0:00:00.5 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 1.3 MB/s eta 0:00:005.5 MB/s eta 0:00:01
# ...
#   WARNING: The script mako-render is installed in '/home/6496ae38-be5e-4185-888d-3c1bd5012183/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script alembic is installed in '/home/6496ae38-be5e-4185-888d-3c1bd5012183/.local/bin' which is not on PATH.
# ...

# %%
import starsim as ss
# Out:
# Starsim 2.0.0 (2024-10-01) — © 2023-2024 by IDM

# %%
sim = ss.Sim(diseases='sir', networks='random') # Create the sim

# %%
sim.run() # Run the sim
# Out:
# Initializing sim with 10000 agents
#   Running 2000.0 ( 0/51) (0.00 s)  ———————————————————— 2%
#   Running 2010.0 (10/51) (0.94 s)  ••••———————————————— 22%
#   Running 2020.0 (20/51) (1.04 s)  ••••••••———————————— 41%
#   Running 2030.0 (30/51) (1.14 s)  ••••••••••••———————— 61%
#   Running 2040.0 (40/51) (1.22 s)  ••••••••••••••••———— 80%
#   Running 2050.0 (50/51) (1.30 s)  •••••••••••••••••••• 100%
# Sim(n=10000; 2000—2050; networks=randomnet; diseases=sir)

# %%
sim.plot() # Plot the results
